# %%
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import torch
from osgeo import gdal
from PIL import Image

def adaptive_resize(array, new_shape):
    # reshape the labels to the size of the image
    single_band = Image.fromarray(array)
    single_band_resized = single_band.resize(new_shape, Image.NEAREST)
    return np.asarray(single_band_resized)

def fix(target_image):
    # we fix the label by
    # 1. Converting all NULL (0) pixels to Non-forest pixels (1)
    # this will convert all null pixels to non-forest pixels
    target_image[target_image == 0] = 1
    # 2. Subtracting 1 from all labels => Non-forest = 0, Forest = 1
    target_image -= 1
    return target_image

def get_images_from_large_file(data_directory_path, label_directory_path, destination, bands, year, region, stride):
    image_path = os.path.join(data_directory_path, 'landsat8_28992_2017_{}.tif'.format(region))
    label_path = os.path.join(label_directory_path,'{}_{}.tiff'.format(region, year))
    if not os.path.exists(destination):
        print('Log: Making parent directory: {}'.format(destination))
        os.mkdir(destination)
    print(image_path, "\n", label_path)
    with open(label_path) as f: pass
    with open(image_path) as f: pass
    # we will use this to divide those fnf images
    covermap = gdal.Open(label_path, gdal.GA_ReadOnly)
    channel = covermap.GetRasterBand(1)
    label = channel.ReadAsArray()
    image_ds = gdal.Open(image_path, gdal.GA_ReadOnly)
    x_size, y_size = image_ds.RasterXSize, image_ds.RasterYSize
    # we need the difference of the two raster sizes to do the resizing
    label = adaptive_resize(label, new_shape=(x_size, y_size))
    all_raster_bands = [image_ds.GetRasterBand(x) for x in bands]
    count = 1
    for i in range(y_size // stride):
        for j in range(x_size // stride):
            # read the label and drop this sample if it has all null pixels
            label_subset = label[i * stride:(i + 1) * stride, j * stride:(j + 1) * stride]
            # 0.01*256*256 ~ 650 pixels i.e at least 1% pixels should be valid
            if np.count_nonzero(label_subset) < 600:
                print("(LOG): Dropping NULL Pixel Sample")
                continue
            # read the raster band by band for this subset
            example_subset = np.nan_to_num(all_raster_bands[0].ReadAsArray(j * stride, i * stride, stride, stride))
            for band in all_raster_bands[1:]:
                example_subset = np.dstack((example_subset, np.nan_to_num(band.ReadAsArray(j * stride, i * stride, stride, stride))))
            # save this example/label pair of numpy arrays as a pickle file with an index
            this_example_save_path = os.path.join(destination, '{}_{}_{}.pkl'.format(region, year, count))
            with open(this_example_save_path, 'wb') as this_pickle:
                pickle.dump((example_subset, label_subset), file=this_pickle, protocol=pickle.HIGHEST_PROTOCOL)
                print('log: Saved {} '.format(this_example_save_path))
                print(i * stride, (i + 1) * stride, j * stride, (j + 1) * stride)
            count += 1

def mask_landsat8_image_using_rasterized_shapefile(rasterized_shapefiles_path, district, this_landsat8_bands_list):
    this_shapefile_path = os.path.join(rasterized_shapefiles_path, "{}_shapefile.tif".format(district))
    ds = gdal.Open(this_shapefile_path)
    assert ds.RasterCount == 1
    shapefile_mask = np.array(ds.GetRasterBand(1).ReadAsArray(), dtype=np.uint8)
    clipped_full_spectrum = list()
    for idx, this_band in enumerate(this_landsat8_bands_list):
        print("{}: Band-{} Size: {}".format(district, idx, this_band.shape))
        clipped_full_spectrum.append(np.multiply(this_band, shapefile_mask))
    x_prev, y_prev = clipped_full_spectrum[0].shape
    x_fixed, y_fixed = int(128 * np.ceil(x_prev / 128)), int(128 * np.ceil(y_prev / 128))
    diff_x, diff_y = x_fixed - x_prev, y_fixed - y_prev
    diff_x_before, diff_y_before = diff_x // 2, diff_y // 2
    clipped_full_spectrum_resized = [np.pad(x, [(diff_x_before, diff_x - diff_x_before), (diff_y_before, diff_y - diff_y_before)], mode='constant')
        for x in clipped_full_spectrum]
    print("{}: Generated Image Size: {}".format(district, clipped_full_spectrum_resized[0].shape, len(clipped_full_spectrum_resized)))
    return clipped_full_spectrum_resized

def check_generated_dataset(path_to_dataset):
    for count in range(266):
        this_example_save_path = os.path.join(path_to_dataset, '{}.pkl'.format(count))
        with open(this_example_save_path, 'rb') as this_pickle:
            print('log: Reading {}'.format(this_example_save_path))
            (example_subset, label_subset) = pickle.load(this_pickle, encoding='latin1')
        show_image = np.asarray(255 * (example_subset[:, :, [4, 3, 2]] / 4096.0).clip(0, 1), dtype=np.uint8)
        plt.subplot(1, 2, 1)
        plt.imshow(show_image)
        plt.subplot(1, 2, 2)
        plt.imshow(label_subset)
        plt.show()

def check_generated_fnf_datapickle(example_path):
    with open(example_path, 'rb') as this_pickle:
        (example_subset, label_subset) = pickle.load(this_pickle, encoding='latin1')
        example_subset = np.nan_to_num(example_subset)
        label_subset = fix(np.nan_to_num(label_subset))
    this = np.asarray(255 * (example_subset[:, :, [3, 2, 1]]), dtype=np.uint8)
    that = label_subset
    plt.subplot(121)
    plt.imshow(this)
    plt.subplot(122)
    plt.imshow(that)
    plt.show()

def toTensor(image, label, one_hot=True):
    '''will convert image and label from numpy to torch tensor'''
    # swap color axis because
    # numpy image: H x W x C
    # torch image: C X H X W
    image = image.transpose((2, 0, 1))
    img_tensor = torch.from_numpy(image).float()
    if one_hot:
        label = label.transpose((2, 0, 1))
        label_tensor = torch.from_numpy(label).float()
    else:
        label_tensor = torch.from_numpy(label).long()
    return img_tensor, label_tensor

def get_indices(arr):
    bands = {
        "ndvi": (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + arr[:, :, 3] + 1e-7),
        "evi": 2.5 * (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + 6 * arr[:, :, 3] - 7.5 * arr[:, :, 1] + 1),
        "savi": 1.5 * (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + arr[:, :, 3] + 0.5),
        "msavi": 0.5 * (2 * arr[:, :, 4] + 1 - np.sqrt((2 * arr[:, :, 4] + 1) ** 2 - 8 * (arr[:, :, 4] - arr[:, :, 3]))),
        "ndmi": (arr[:, :, 4] - arr[:, :, 5]) / (arr[:, :, 4] + arr[:, :, 5] + 1e-7),
        "nbr": (arr[:, :, 4] - arr[:, :, 6]) / (arr[:, :, 4] + arr[:, :, 6] + 1e-7),
        "nbr2": (arr[:, :, 5] - arr[:, :, 6]) / (arr[:, :, 5] + arr[:, :, 6] + 1e-7),
    }
    for name in bands:
        value = np.nan_to_num(bands[name])
        arr = np.dstack((arr, value))
    return arr

def main():
    # change these!
    data_directory_path = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train"
    label_directory_path = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images"
    destination = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data"
    # generate pickle files to train from
    all_districts = ["Drenthe", "Flevoland", "Limburg", "Gelderland", "Friesland", "Groningen", "Noord Brabant", 
                     "Overijssel", "Noord Holland", "Zuid Holland", "Zeeland", "Utrecht"]
    # number of images generated depends on value of stride
    for district in all_districts:
        get_images_from_large_file(data_directory_path, label_directory_path, destination, 
                                   bands=range(1, 12), year=2017, region=district, stride=256)


if __name__ == "__main__":
    main()
# Out:
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Drenthe.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Drenthe_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_1.pkl
# 0 256 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_2.pkl
# 0 256 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_3.pkl
# 0 256 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_4.pkl
# 256 512 256 512
# <ipython-input-1-3473d4b2880b>:12: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   single_band_resized = single_band.resize(new_shape, Image.NEAREST)
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_5.pkl
# 256 512 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_6.pkl
# 256 512 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_7.pkl
# 256 512 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_8.pkl
# 256 512 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_9.pkl
# 256 512 1536 1792
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_10.pkl
# 512 768 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_11.pkl
# 512 768 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_12.pkl
# 512 768 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_13.pkl
# 512 768 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_14.pkl
# 512 768 1536 1792
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_15.pkl
# 768 1024 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_16.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_17.pkl
# 768 1024 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_18.pkl
# 768 1024 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_19.pkl
# 768 1024 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_20.pkl
# 768 1024 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_21.pkl
# 1024 1280 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_22.pkl
# 1024 1280 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_23.pkl
# 1024 1280 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_24.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_25.pkl
# 1024 1280 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_26.pkl
# 1024 1280 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_27.pkl
# 1024 1280 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_28.pkl
# 1024 1280 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_29.pkl
# 1280 1536 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_30.pkl
# 1280 1536 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_31.pkl
# 1280 1536 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_32.pkl
# 1280 1536 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_33.pkl
# 1280 1536 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_34.pkl
# 1280 1536 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_35.pkl
# 1280 1536 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_36.pkl
# 1280 1536 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_37.pkl
# 1536 1792 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_38.pkl
# 1536 1792 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_39.pkl
# 1536 1792 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_40.pkl
# 1536 1792 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_41.pkl
# 1536 1792 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_42.pkl
# 1536 1792 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_43.pkl
# 1536 1792 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_44.pkl
# 1536 1792 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_45.pkl
# 1792 2048 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_46.pkl
# 1792 2048 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_47.pkl
# 1792 2048 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_48.pkl
# 1792 2048 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_49.pkl
# 1792 2048 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_50.pkl
# 1792 2048 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_51.pkl
# 1792 2048 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Drenthe_2017_52.pkl
# 1792 2048 1792 2048
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Flevoland.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Flevoland_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_1.pkl
# 0 256 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_2.pkl
# 0 256 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_3.pkl
# 0 256 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_4.pkl
# 0 256 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_5.pkl
# 0 256 1792 2048
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_6.pkl
# 256 512 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_7.pkl
# 256 512 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_8.pkl
# 256 512 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_9.pkl
# 256 512 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_10.pkl
# 256 512 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_11.pkl
# 256 512 1792 2048
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_12.pkl
# 512 768 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_13.pkl
# 512 768 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_14.pkl
# 512 768 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_15.pkl
# 512 768 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_16.pkl
# 512 768 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_17.pkl
# 512 768 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_18.pkl
# 512 768 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_19.pkl
# 768 1024 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_20.pkl
# 768 1024 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_21.pkl
# 768 1024 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_22.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_23.pkl
# 768 1024 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_24.pkl
# 768 1024 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_25.pkl
# 768 1024 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_26.pkl
# 768 1024 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_27.pkl
# 1024 1280 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_28.pkl
# 1024 1280 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_29.pkl
# 1024 1280 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_30.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_31.pkl
# 1024 1280 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_32.pkl
# 1024 1280 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_33.pkl
# 1024 1280 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_34.pkl
# 1024 1280 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_35.pkl
# 1280 1536 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_36.pkl
# 1280 1536 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_37.pkl
# 1280 1536 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_38.pkl
# 1280 1536 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_39.pkl
# 1280 1536 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_40.pkl
# 1280 1536 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_41.pkl
# 1280 1536 1536 1792
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_42.pkl
# 1536 1792 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_43.pkl
# 1536 1792 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_44.pkl
# 1536 1792 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_45.pkl
# 1536 1792 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_46.pkl
# 1536 1792 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_47.pkl
# 1536 1792 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_48.pkl
# 1536 1792 1536 1792
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_49.pkl
# 1792 2048 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_50.pkl
# 1792 2048 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_51.pkl
# 1792 2048 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_52.pkl
# 1792 2048 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Flevoland_2017_53.pkl
# 1792 2048 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Limburg.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Limburg_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_1.pkl
# 0 256 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_2.pkl
# 0 256 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_3.pkl
# 0 256 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_4.pkl
# 256 512 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_5.pkl
# 256 512 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_6.pkl
# 512 768 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_7.pkl
# 512 768 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_8.pkl
# 768 1024 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_9.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_10.pkl
# 768 1024 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_11.pkl
# 1024 1280 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_12.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_13.pkl
# 1024 1280 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_14.pkl
# 1280 1536 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_15.pkl
# 1280 1536 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_16.pkl
# 1536 1792 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_17.pkl
# 1536 1792 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_18.pkl
# 1536 1792 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_19.pkl
# 1536 1792 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_20.pkl
# 1536 1792 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_21.pkl
# 1792 2048 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_22.pkl
# 1792 2048 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_23.pkl
# 1792 2048 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_24.pkl
# 1792 2048 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_25.pkl
# 1792 2048 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_26.pkl
# 2048 2304 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_27.pkl
# 2048 2304 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_28.pkl
# 2048 2304 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_29.pkl
# 2048 2304 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_30.pkl
# 2048 2304 1024 1280
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_31.pkl
# 2304 2560 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_32.pkl
# 2304 2560 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_33.pkl
# 2304 2560 1024 1280
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_34.pkl
# 2560 2816 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_35.pkl
# 2560 2816 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_36.pkl
# 2560 2816 768 1024
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_37.pkl
# 2816 3072 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_38.pkl
# 2816 3072 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_39.pkl
# 2816 3072 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_40.pkl
# 2816 3072 1024 1280
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_41.pkl
# 3072 3328 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_42.pkl
# 3072 3328 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_43.pkl
# 3072 3328 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_44.pkl
# 3072 3328 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_45.pkl
# 3328 3584 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_46.pkl
# 3328 3584 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_47.pkl
# 3328 3584 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_48.pkl
# 3328 3584 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Limburg_2017_49.pkl
# 3328 3584 1024 1280
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Gelderland.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Gelderland_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_1.pkl
# 0 256 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_2.pkl
# 0 256 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_3.pkl
# 0 256 2304 2560
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_4.pkl
# 256 512 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_5.pkl
# 256 512 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_6.pkl
# 256 512 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_7.pkl
# 256 512 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_8.pkl
# 256 512 2560 2816
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_9.pkl
# 512 768 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_10.pkl
# 512 768 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_11.pkl
# 512 768 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_12.pkl
# 512 768 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_13.pkl
# 512 768 2304 2560
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_14.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_15.pkl
# 768 1024 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_16.pkl
# 768 1024 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_17.pkl
# 768 1024 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_18.pkl
# 768 1024 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_19.pkl
# 768 1024 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_20.pkl
# 768 1024 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_21.pkl
# 768 1024 2560 2816
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_22.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_23.pkl
# 1024 1280 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_24.pkl
# 1024 1280 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_25.pkl
# 1024 1280 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_26.pkl
# 1024 1280 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_27.pkl
# 1024 1280 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_28.pkl
# 1024 1280 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_29.pkl
# 1024 1280 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_30.pkl
# 1024 1280 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_31.pkl
# 1024 1280 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_32.pkl
# 1024 1280 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_33.pkl
# 1024 1280 3584 3840
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_34.pkl
# 1280 1536 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_35.pkl
# 1280 1536 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_36.pkl
# 1280 1536 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_37.pkl
# 1280 1536 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_38.pkl
# 1280 1536 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_39.pkl
# 1280 1536 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_40.pkl
# 1280 1536 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_41.pkl
# 1280 1536 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_42.pkl
# 1280 1536 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_43.pkl
# 1280 1536 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_44.pkl
# 1280 1536 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_45.pkl
# 1280 1536 3840 4096
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_46.pkl
# 1536 1792 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_47.pkl
# 1536 1792 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_48.pkl
# 1536 1792 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_49.pkl
# 1536 1792 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_50.pkl
# 1536 1792 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_51.pkl
# 1536 1792 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_52.pkl
# 1536 1792 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_53.pkl
# 1536 1792 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_54.pkl
# 1536 1792 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_55.pkl
# 1536 1792 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_56.pkl
# 1536 1792 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_57.pkl
# 1536 1792 3840 4096
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_58.pkl
# 1792 2048 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_59.pkl
# 1792 2048 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_60.pkl
# 1792 2048 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_61.pkl
# 1792 2048 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_62.pkl
# 1792 2048 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_63.pkl
# 1792 2048 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_64.pkl
# 1792 2048 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_65.pkl
# 1792 2048 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_66.pkl
# 1792 2048 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_67.pkl
# 1792 2048 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_68.pkl
# 1792 2048 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_69.pkl
# 1792 2048 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_70.pkl
# 1792 2048 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_71.pkl
# 1792 2048 3840 4096
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_72.pkl
# 2048 2304 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_73.pkl
# 2048 2304 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_74.pkl
# 2048 2304 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_75.pkl
# 2048 2304 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_76.pkl
# 2048 2304 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_77.pkl
# 2048 2304 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_78.pkl
# 2048 2304 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_79.pkl
# 2048 2304 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_80.pkl
# 2048 2304 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_81.pkl
# 2048 2304 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_82.pkl
# 2048 2304 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_83.pkl
# 2048 2304 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_84.pkl
# 2048 2304 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_85.pkl
# 2048 2304 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_86.pkl
# 2048 2304 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_87.pkl
# 2304 2560 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_88.pkl
# 2304 2560 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_89.pkl
# 2304 2560 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_90.pkl
# 2304 2560 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_91.pkl
# 2304 2560 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_92.pkl
# 2304 2560 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_93.pkl
# 2304 2560 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_94.pkl
# 2304 2560 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_95.pkl
# 2304 2560 2048 2304
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_96.pkl
# 2304 2560 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_97.pkl
# 2304 2560 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_98.pkl
# 2304 2560 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_99.pkl
# 2304 2560 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_100.pkl
# 2304 2560 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_101.pkl
# 2304 2560 3584 3840
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_102.pkl
# 2560 2816 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_103.pkl
# 2560 2816 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_104.pkl
# 2560 2816 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_105.pkl
# 2560 2816 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_106.pkl
# 2560 2816 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_107.pkl
# 2560 2816 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_108.pkl
# 2560 2816 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_109.pkl
# 2560 2816 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Gelderland_2017_110.pkl
# 2560 2816 2048 2304
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Friesland.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Friesland_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_1.pkl
# 0 256 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_2.pkl
# 0 256 1792 2048
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_3.pkl
# 0 256 2304 2560
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_4.pkl
# 0 256 2560 2816
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_5.pkl
# 0 256 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_6.pkl
# 0 256 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_7.pkl
# 0 256 3328 3584
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Friesland_2017_8.pkl
# 256 512 768 1024
# ...
# 2048 2304 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zuid Holland_2017_68.pkl
# 2048 2304 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zuid Holland_2017_69.pkl
# 2048 2304 2048 2304
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Zeeland.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Zeeland_2017.tiff
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_1.pkl
# 0 256 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_2.pkl
# 0 256 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_3.pkl
# 0 256 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_4.pkl
# 0 256 1536 1792
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_5.pkl
# 256 512 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_6.pkl
# 256 512 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_7.pkl
# 256 512 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_8.pkl
# 256 512 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_9.pkl
# 256 512 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_10.pkl
# 256 512 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_11.pkl
# 512 768 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_12.pkl
# 512 768 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_13.pkl
# 512 768 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_14.pkl
# 512 768 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_15.pkl
# 512 768 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_16.pkl
# 512 768 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_17.pkl
# 512 768 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_18.pkl
# 512 768 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_19.pkl
# 768 1024 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_20.pkl
# 768 1024 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_21.pkl
# 768 1024 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_22.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_23.pkl
# 768 1024 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_24.pkl
# 768 1024 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_25.pkl
# 768 1024 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_26.pkl
# 768 1024 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_27.pkl
# 1024 1280 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_28.pkl
# 1024 1280 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_29.pkl
# 1024 1280 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_30.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_31.pkl
# 1024 1280 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_32.pkl
# 1024 1280 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_33.pkl
# 1024 1280 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_34.pkl
# 1024 1280 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_35.pkl
# 1280 1536 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_36.pkl
# 1280 1536 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_37.pkl
# 1280 1536 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_38.pkl
# 1280 1536 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_39.pkl
# 1280 1536 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_40.pkl
# 1280 1536 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_41.pkl
# 1280 1536 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_42.pkl
# 1280 1536 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_43.pkl
# 1536 1792 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_44.pkl
# 1536 1792 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_45.pkl
# 1536 1792 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_46.pkl
# 1536 1792 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_47.pkl
# 1536 1792 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_48.pkl
# 1536 1792 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_49.pkl
# 1536 1792 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_50.pkl
# 1536 1792 1792 2048
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_51.pkl
# 1792 2048 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_52.pkl
# 1792 2048 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_53.pkl
# 1792 2048 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_54.pkl
# 1792 2048 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_55.pkl
# 1792 2048 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_56.pkl
# 1792 2048 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_57.pkl
# 1792 2048 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Zeeland_2017_58.pkl
# 1792 2048 1792 2048
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\landsat8_28992_2017_Utrecht.tif
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Utrecht_2017.tiff
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_1.pkl
# 0 256 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_2.pkl
# 0 256 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_3.pkl
# 0 256 512 768
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_4.pkl
# 0 256 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_5.pkl
# 0 256 1280 1536
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_6.pkl
# 256 512 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_7.pkl
# 256 512 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_8.pkl
# 256 512 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_9.pkl
# 256 512 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_10.pkl
# 256 512 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_11.pkl
# 256 512 1280 1536
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_12.pkl
# 512 768 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_13.pkl
# 512 768 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_14.pkl
# 512 768 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_15.pkl
# 512 768 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_16.pkl
# 512 768 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_17.pkl
# 512 768 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_18.pkl
# 512 768 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_19.pkl
# 768 1024 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_20.pkl
# 768 1024 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_21.pkl
# 768 1024 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_22.pkl
# 768 1024 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_23.pkl
# 768 1024 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_24.pkl
# 768 1024 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_25.pkl
# 768 1024 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_26.pkl
# 1024 1280 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_27.pkl
# 1024 1280 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_28.pkl
# 1024 1280 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_29.pkl
# 1024 1280 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_30.pkl
# 1024 1280 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_31.pkl
# 1024 1280 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_32.pkl
# 1024 1280 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_33.pkl
# 1280 1536 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_34.pkl
# 1280 1536 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_35.pkl
# 1280 1536 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_36.pkl
# 1280 1536 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_37.pkl
# 1280 1536 1024 1280
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\training_2017_pickled_data\Utrecht_2017_38.pkl
# 1280 1536 1536 1792
