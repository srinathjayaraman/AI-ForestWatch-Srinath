# %%
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import torch
from osgeo import gdal
from PIL import Image

def adaptive_resize(array, new_shape):
    # reshape the labels to the size of the image
    single_band = Image.fromarray(array)
    single_band_resized = single_band.resize(new_shape, Image.NEAREST)
    return np.asarray(single_band_resized)

def fix(target_image):
    # we fix the label by
    # 1. Converting all NULL (0) pixels to Non-forest pixels (1)
    # this will convert all null pixels to non-forest pixels
    target_image[target_image == 0] = 1
    # 2. Subtracting 1 from all labels => Non-forest = 0, Forest = 1
    target_image -= 1
    return target_image

def get_images_from_large_file(data_directory_path, label_directory_path, destination, bands, year, region, stride):
    image_path = os.path.join(data_directory_path, 'landsat8_{}_region_{}.tiff'.format(year, region))
    label_path = os.path.join(label_directory_path,'{}_{}.tiff'.format(region, year))
    if not os.path.exists(destination):
        print('Log: Making parent directory: {}'.format(destination))
        os.mkdir(destination)
    print(image_path, "\n", label_path)
    with open(label_path) as f: pass
    with open(image_path) as f: pass
    # we will use this to divide those fnf images
    covermap = gdal.Open(label_path, gdal.GA_ReadOnly)
    channel = covermap.GetRasterBand(1)
    label = channel.ReadAsArray()
    image_ds = gdal.Open(image_path, gdal.GA_ReadOnly)
    x_size, y_size = image_ds.RasterXSize, image_ds.RasterYSize
    # we need the difference of the two raster sizes to do the resizing
    label = adaptive_resize(label, new_shape=(x_size, y_size))
    all_raster_bands = [image_ds.GetRasterBand(x) for x in bands]
    count = 1
    for i in range(y_size // stride):
        for j in range(x_size // stride):
            # read the label and drop this sample if it has all null pixels
            label_subset = label[i * stride:(i + 1) * stride, j * stride:(j + 1) * stride]
            # 0.01*256*256 ~ 650 pixels i.e at least 1% pixels should be valid
            if np.count_nonzero(label_subset) < 600:
                print("(LOG): Dropping NULL Pixel Sample")
                continue
            # read the raster band by band for this subset
            example_subset = np.nan_to_num(all_raster_bands[0].ReadAsArray(j * stride, i * stride, stride, stride))
            for band in all_raster_bands[1:]:
                example_subset = np.dstack((example_subset, np.nan_to_num(band.ReadAsArray(j * stride, i * stride, stride, stride))))
            # save this example/label pair of numpy arrays as a pickle file with an index
            this_example_save_path = os.path.join(destination, '{}_{}_{}.pkl'.format(region, year, count))
            with open(this_example_save_path, 'wb') as this_pickle:
                pickle.dump((example_subset, label_subset), file=this_pickle, protocol=pickle.HIGHEST_PROTOCOL)
                print('log: Saved {} '.format(this_example_save_path))
                print(i * stride, (i + 1) * stride, j * stride, (j + 1) * stride)
            count += 1

def mask_landsat8_image_using_rasterized_shapefile(rasterized_shapefiles_path, district, this_landsat8_bands_list):
    this_shapefile_path = os.path.join(rasterized_shapefiles_path, "{}_shapefile.tif".format(district))
    ds = gdal.Open(this_shapefile_path)
    assert ds.RasterCount == 1
    shapefile_mask = np.array(ds.GetRasterBand(1).ReadAsArray(), dtype=np.uint8)
    clipped_full_spectrum = list()
    for idx, this_band in enumerate(this_landsat8_bands_list):
        print("{}: Band-{} Size: {}".format(district, idx, this_band.shape))
        clipped_full_spectrum.append(np.multiply(this_band, shapefile_mask))
    x_prev, y_prev = clipped_full_spectrum[0].shape
    x_fixed, y_fixed = int(128 * np.ceil(x_prev / 128)), int(128 * np.ceil(y_prev / 128))
    diff_x, diff_y = x_fixed - x_prev, y_fixed - y_prev
    diff_x_before, diff_y_before = diff_x // 2, diff_y // 2
    clipped_full_spectrum_resized = [np.pad(x, [(diff_x_before, diff_x - diff_x_before), (diff_y_before, diff_y - diff_y_before)], mode='constant')
        for x in clipped_full_spectrum]
    print("{}: Generated Image Size: {}".format(district, clipped_full_spectrum_resized[0].shape, len(clipped_full_spectrum_resized)))
    return clipped_full_spectrum_resized

def check_generated_dataset(path_to_dataset):
    for count in range(266):
        this_example_save_path = os.path.join(path_to_dataset, '{}.pkl'.format(count))
        with open(this_example_save_path, 'rb') as this_pickle:
            print('log: Reading {}'.format(this_example_save_path))
            (example_subset, label_subset) = pickle.load(this_pickle, encoding='latin1')
        show_image = np.asarray(255 * (example_subset[:, :, [4, 3, 2]] / 4096.0).clip(0, 1), dtype=np.uint8)
        plt.subplot(1, 2, 1)
        plt.imshow(show_image)
        plt.subplot(1, 2, 2)
        plt.imshow(label_subset)
        plt.show()

def check_generated_fnf_datapickle(example_path):
    with open(example_path, 'rb') as this_pickle:
        (example_subset, label_subset) = pickle.load(this_pickle, encoding='latin1')
        example_subset = np.nan_to_num(example_subset)
        label_subset = fix(np.nan_to_num(label_subset))
    this = np.asarray(255 * (example_subset[:, :, [3, 2, 1]]), dtype=np.uint8)
    that = label_subset
    plt.subplot(121)
    plt.imshow(this)
    plt.subplot(122)
    plt.imshow(that)
    plt.show()

def toTensor(image, label, one_hot=True):
    '''will convert image and label from numpy to torch tensor'''
    # swap color axis because
    # numpy image: H x W x C
    # torch image: C X H X W
    image = image.transpose((2, 0, 1))
    img_tensor = torch.from_numpy(image).float()
    if one_hot:
        label = label.transpose((2, 0, 1))
        label_tensor = torch.from_numpy(label).float()
    else:
        label_tensor = torch.from_numpy(label).long()
    return img_tensor, label_tensor

def get_indices(arr):
    bands = {
        "ndvi": (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + arr[:, :, 3] + 1e-7),
        "evi": 2.5 * (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + 6 * arr[:, :, 3] - 7.5 * arr[:, :, 1] + 1),
        "savi": 1.5 * (arr[:, :, 4] - arr[:, :, 3]) / (arr[:, :, 4] + arr[:, :, 3] + 0.5),
        "msavi": 0.5 * (2 * arr[:, :, 4] + 1 - np.sqrt((2 * arr[:, :, 4] + 1) ** 2 - 8 * (arr[:, :, 4] - arr[:, :, 3]))),
        "ndmi": (arr[:, :, 4] - arr[:, :, 5]) / (arr[:, :, 4] + arr[:, :, 5] + 1e-7),
        "nbr": (arr[:, :, 4] - arr[:, :, 6]) / (arr[:, :, 4] + arr[:, :, 6] + 1e-7),
        "nbr2": (arr[:, :, 5] - arr[:, :, 6]) / (arr[:, :, 5] + arr[:, :, 6] + 1e-7),
    }
    for name in bands:
        value = np.nan_to_num(bands[name])
        arr = np.dstack((arr, value))
    return arr

def main():
    # change these!
    data_directory_path = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\inference\images"
    label_directory_path = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images"
    destination = r"E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train"
    # generate pickle files to train from
    all_districts = ["Netherlands"]
    # number of images generated depends on value of stride
    for district in all_districts:
        get_images_from_large_file(data_directory_path, label_directory_path, destination, bands=range(1, 12), year=2015, region=district, stride=256)


if __name__ == "__main__":
    main()
# Out:
# E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\inference\images\landsat8_2015_region_Netherlands.tiff
#  E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\Ground Truth Images\Netherlands_2015.tiff
# <ipython-input-2-b33a075c6cdd>:12: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   single_band_resized = single_band.resize(new_shape, Image.NEAREST)
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_1.pkl
# 0 256 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_2.pkl
# 0 256 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_3.pkl
# 0 256 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_4.pkl
# 0 256 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_5.pkl
# 0 256 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_6.pkl
# 0 256 7680 7936
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_7.pkl
# 256 512 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_8.pkl
# 256 512 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_9.pkl
# 256 512 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_10.pkl
# 256 512 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_11.pkl
# 256 512 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_12.pkl
# 256 512 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_13.pkl
# 256 512 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_14.pkl
# 256 512 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_15.pkl
# 256 512 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_16.pkl
# 256 512 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_17.pkl
# 256 512 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_18.pkl
# 256 512 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_19.pkl
# 256 512 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_20.pkl
# 256 512 8192 8448
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_21.pkl
# 512 768 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_22.pkl
# 512 768 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_23.pkl
# 512 768 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_24.pkl
# 512 768 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_25.pkl
# 512 768 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_26.pkl
# 512 768 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_27.pkl
# 512 768 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_28.pkl
# 512 768 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_29.pkl
# 512 768 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_30.pkl
# 512 768 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_31.pkl
# 512 768 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_32.pkl
# 512 768 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_33.pkl
# 512 768 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_34.pkl
# 512 768 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_35.pkl
# 512 768 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_36.pkl
# 512 768 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_37.pkl
# 512 768 8192 8448
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_38.pkl
# 768 1024 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_39.pkl
# 768 1024 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_40.pkl
# 768 1024 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_41.pkl
# 768 1024 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_42.pkl
# 768 1024 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_43.pkl
# 768 1024 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_44.pkl
# 768 1024 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_45.pkl
# 768 1024 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_46.pkl
# 768 1024 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_47.pkl
# 768 1024 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_48.pkl
# 768 1024 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_49.pkl
# 768 1024 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_50.pkl
# 768 1024 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_51.pkl
# 768 1024 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_52.pkl
# 768 1024 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_53.pkl
# 768 1024 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_54.pkl
# 768 1024 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_55.pkl
# 768 1024 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_56.pkl
# 768 1024 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_57.pkl
# 1024 1280 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_58.pkl
# 1024 1280 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_59.pkl
# 1024 1280 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_60.pkl
# 1024 1280 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_61.pkl
# 1024 1280 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_62.pkl
# 1024 1280 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_63.pkl
# 1024 1280 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_64.pkl
# 1024 1280 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_65.pkl
# 1024 1280 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_66.pkl
# 1024 1280 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_67.pkl
# 1024 1280 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_68.pkl
# 1024 1280 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_69.pkl
# 1024 1280 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_70.pkl
# 1024 1280 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_71.pkl
# 1024 1280 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_72.pkl
# 1024 1280 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_73.pkl
# 1024 1280 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_74.pkl
# 1024 1280 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_75.pkl
# 1024 1280 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_76.pkl
# 1024 1280 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_77.pkl
# 1280 1536 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_78.pkl
# 1280 1536 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_79.pkl
# 1280 1536 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_80.pkl
# 1280 1536 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_81.pkl
# 1280 1536 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_82.pkl
# 1280 1536 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_83.pkl
# 1280 1536 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_84.pkl
# 1280 1536 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_85.pkl
# 1280 1536 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_86.pkl
# 1280 1536 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_87.pkl
# 1280 1536 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_88.pkl
# 1280 1536 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_89.pkl
# 1280 1536 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_90.pkl
# 1280 1536 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_91.pkl
# 1280 1536 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_92.pkl
# 1280 1536 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_93.pkl
# 1280 1536 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_94.pkl
# 1280 1536 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_95.pkl
# 1280 1536 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_96.pkl
# 1280 1536 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_97.pkl
# 1280 1536 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_98.pkl
# 1536 1792 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_99.pkl
# 1536 1792 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_100.pkl
# 1536 1792 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_101.pkl
# 1536 1792 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_102.pkl
# 1536 1792 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_103.pkl
# 1536 1792 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_104.pkl
# 1536 1792 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_105.pkl
# 1536 1792 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_106.pkl
# 1536 1792 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_107.pkl
# 1536 1792 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_108.pkl
# 1536 1792 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_109.pkl
# 1536 1792 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_110.pkl
# 1536 1792 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_111.pkl
# 1536 1792 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_112.pkl
# 1536 1792 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_113.pkl
# 1536 1792 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_114.pkl
# 1536 1792 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_115.pkl
# 1536 1792 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_116.pkl
# 1536 1792 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_117.pkl
# 1536 1792 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_118.pkl
# 1536 1792 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_119.pkl
# 1792 2048 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_120.pkl
# 1792 2048 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_121.pkl
# 1792 2048 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_122.pkl
# 1792 2048 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_123.pkl
# 1792 2048 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_124.pkl
# 1792 2048 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_125.pkl
# 1792 2048 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_126.pkl
# 1792 2048 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_127.pkl
# 1792 2048 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_128.pkl
# 1792 2048 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_129.pkl
# 1792 2048 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_130.pkl
# 1792 2048 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_131.pkl
# 1792 2048 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_132.pkl
# 1792 2048 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_133.pkl
# 1792 2048 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_134.pkl
# 1792 2048 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_135.pkl
# 1792 2048 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_136.pkl
# 1792 2048 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_137.pkl
# 1792 2048 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_138.pkl
# 1792 2048 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_139.pkl
# 1792 2048 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_140.pkl
# 1792 2048 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_141.pkl
# 2048 2304 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_142.pkl
# 2048 2304 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_143.pkl
# 2048 2304 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_144.pkl
# 2048 2304 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_145.pkl
# 2048 2304 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_146.pkl
# 2048 2304 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_147.pkl
# 2048 2304 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_148.pkl
# 2048 2304 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_149.pkl
# 2048 2304 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_150.pkl
# 2048 2304 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_151.pkl
# 2048 2304 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_152.pkl
# 2048 2304 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_153.pkl
# 2048 2304 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_154.pkl
# 2048 2304 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_155.pkl
# 2048 2304 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_156.pkl
# 2048 2304 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_157.pkl
# 2048 2304 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_158.pkl
# 2048 2304 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_159.pkl
# 2048 2304 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_160.pkl
# 2048 2304 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_161.pkl
# 2048 2304 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_162.pkl
# 2048 2304 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_163.pkl
# 2304 2560 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_164.pkl
# 2304 2560 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_165.pkl
# 2304 2560 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_166.pkl
# 2304 2560 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_167.pkl
# 2304 2560 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_168.pkl
# 2304 2560 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_169.pkl
# 2304 2560 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_170.pkl
# 2304 2560 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_171.pkl
# 2304 2560 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_172.pkl
# 2304 2560 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_173.pkl
# 2304 2560 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_174.pkl
# 2304 2560 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_175.pkl
# 2304 2560 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_176.pkl
# 2304 2560 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_177.pkl
# 2304 2560 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_178.pkl
# 2304 2560 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_179.pkl
# 2304 2560 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_180.pkl
# 2304 2560 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_181.pkl
# 2304 2560 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_182.pkl
# 2304 2560 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_183.pkl
# 2304 2560 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_184.pkl
# 2304 2560 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_185.pkl
# 2560 2816 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_186.pkl
# 2560 2816 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_187.pkl
# 2560 2816 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_188.pkl
# 2560 2816 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_189.pkl
# 2560 2816 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_190.pkl
# 2560 2816 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_191.pkl
# 2560 2816 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_192.pkl
# 2560 2816 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_193.pkl
# 2560 2816 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_194.pkl
# 2560 2816 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_195.pkl
# 2560 2816 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_196.pkl
# 2560 2816 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_197.pkl
# 2560 2816 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_198.pkl
# 2560 2816 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_199.pkl
# 2560 2816 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_200.pkl
# 2560 2816 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_201.pkl
# 2560 2816 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_202.pkl
# 2560 2816 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_203.pkl
# 2560 2816 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_204.pkl
# 2560 2816 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_205.pkl
# 2560 2816 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_206.pkl
# 2560 2816 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_207.pkl
# 2816 3072 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_208.pkl
# 2816 3072 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_209.pkl
# 2816 3072 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_210.pkl
# 2816 3072 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_211.pkl
# 2816 3072 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_212.pkl
# 2816 3072 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_213.pkl
# 2816 3072 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_214.pkl
# 2816 3072 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_215.pkl
# 2816 3072 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_216.pkl
# 2816 3072 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_217.pkl
# 2816 3072 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_218.pkl
# 2816 3072 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_219.pkl
# 2816 3072 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_220.pkl
# 2816 3072 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_221.pkl
# 2816 3072 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_222.pkl
# 2816 3072 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_223.pkl
# 2816 3072 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_224.pkl
# 2816 3072 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_225.pkl
# 2816 3072 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_226.pkl
# 2816 3072 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_227.pkl
# 2816 3072 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_228.pkl
# 2816 3072 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_229.pkl
# 3072 3328 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_230.pkl
# 3072 3328 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_231.pkl
# 3072 3328 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_232.pkl
# 3072 3328 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_233.pkl
# 3072 3328 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_234.pkl
# 3072 3328 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_235.pkl
# 3072 3328 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_236.pkl
# 3072 3328 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_237.pkl
# 3072 3328 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_238.pkl
# 3072 3328 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_239.pkl
# 3072 3328 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_240.pkl
# 3072 3328 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_241.pkl
# 3072 3328 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_242.pkl
# 3072 3328 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_243.pkl
# 3072 3328 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_244.pkl
# 3072 3328 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_245.pkl
# 3072 3328 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_246.pkl
# 3072 3328 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_247.pkl
# 3072 3328 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_248.pkl
# 3072 3328 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_249.pkl
# 3072 3328 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_250.pkl
# 3072 3328 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_251.pkl
# 3328 3584 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_252.pkl
# 3328 3584 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_253.pkl
# 3328 3584 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_254.pkl
# 3328 3584 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_255.pkl
# 3328 3584 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_256.pkl
# 3328 3584 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_257.pkl
# 3328 3584 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_258.pkl
# 3328 3584 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_259.pkl
# 3328 3584 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_260.pkl
# 3328 3584 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_261.pkl
# 3328 3584 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_262.pkl
# 3328 3584 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_263.pkl
# 3328 3584 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_264.pkl
# 3328 3584 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_265.pkl
# 3328 3584 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_266.pkl
# 3328 3584 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_267.pkl
# 3328 3584 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_268.pkl
# 3328 3584 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_269.pkl
# 3328 3584 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_270.pkl
# 3328 3584 7680 7936
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_271.pkl
# 3328 3584 7936 8192
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_272.pkl
# 3328 3584 8192 8448
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_273.pkl
# 3328 3584 8448 8704
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_274.pkl
# 3584 3840 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_275.pkl
# 3584 3840 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_276.pkl
# 3584 3840 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_277.pkl
# 3584 3840 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_278.pkl
# 3584 3840 3840 4096
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_279.pkl
# 3584 3840 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_280.pkl
# 3584 3840 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_281.pkl
# 3584 3840 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_282.pkl
# 3584 3840 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_283.pkl
# 3584 3840 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_284.pkl
# 3584 3840 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_285.pkl
# 3584 3840 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_286.pkl
# 3584 3840 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_287.pkl
# 3584 3840 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_288.pkl
# 3584 3840 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_289.pkl
# 3584 3840 6656 6912
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_290.pkl
# 3584 3840 6912 7168
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_291.pkl
# 3584 3840 7168 7424
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_292.pkl
# 3584 3840 7424 7680
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_293.pkl
# 3584 3840 7680 7936
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_294.pkl
# 3840 4096 2816 3072
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_295.pkl
# 3840 4096 3072 3328
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_296.pkl
# 3840 4096 3328 3584
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_297.pkl
# 3840 4096 3584 3840
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_298.pkl
# 3840 4096 3840 4096
# ...
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_724.pkl
# 8192 8448 4096 4352
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_725.pkl
# 8192 8448 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_726.pkl
# 8192 8448 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_727.pkl
# 8192 8448 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_728.pkl
# 8192 8448 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_729.pkl
# 8192 8448 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_730.pkl
# 8192 8448 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_731.pkl
# 8192 8448 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_732.pkl
# 8192 8448 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_733.pkl
# 8192 8448 6400 6656
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_734.pkl
# 8192 8448 6656 6912
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_735.pkl
# 8448 8704 0 256
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_736.pkl
# 8448 8704 256 512
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_737.pkl
# 8448 8704 512 768
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_738.pkl
# 8448 8704 768 1024
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_739.pkl
# 8448 8704 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_740.pkl
# 8448 8704 1280 1536
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_741.pkl
# 8448 8704 1536 1792
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_742.pkl
# 8448 8704 1792 2048
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_743.pkl
# 8448 8704 4352 4608
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_744.pkl
# 8448 8704 4608 4864
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_745.pkl
# 8448 8704 4864 5120
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_746.pkl
# 8448 8704 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_747.pkl
# 8448 8704 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_748.pkl
# 8448 8704 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_749.pkl
# 8448 8704 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_750.pkl
# 8448 8704 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_751.pkl
# 8448 8704 6400 6656
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_752.pkl
# 8704 8960 1024 1280
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_753.pkl
# 8704 8960 1280 1536
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_754.pkl
# 8704 8960 5120 5376
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_755.pkl
# 8704 8960 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_756.pkl
# 8704 8960 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_757.pkl
# 8704 8960 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_758.pkl
# 8704 8960 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_759.pkl
# 8704 8960 6400 6656
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_760.pkl
# 8960 9216 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_761.pkl
# 8960 9216 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_762.pkl
# 8960 9216 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_763.pkl
# 8960 9216 6400 6656
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_764.pkl
# 9216 9472 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_765.pkl
# 9216 9472 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_766.pkl
# 9216 9472 6144 6400
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_767.pkl
# 9472 9728 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_768.pkl
# 9472 9728 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_769.pkl
# 9472 9728 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_770.pkl
# 9472 9728 6144 6400
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_771.pkl
# 9728 9984 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_772.pkl
# 9728 9984 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_773.pkl
# 9728 9984 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_774.pkl
# 9728 9984 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_775.pkl
# 9728 9984 6400 6656
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_776.pkl
# 9984 10240 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_777.pkl
# 9984 10240 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_778.pkl
# 9984 10240 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_779.pkl
# 9984 10240 6144 6400
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_780.pkl
# 9984 10240 6400 6656
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_781.pkl
# 10240 10496 5376 5632
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_782.pkl
# 10240 10496 5632 5888
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_783.pkl
# 10240 10496 5888 6144
# log: Saved E:\Masters\IN5000 - Final Project\AI-ForestWatch-Data\Netherlands data\train\Netherlands_2015_784.pkl
# 10240 10496 6144 6400
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
# (LOG): Dropping NULL Pixel Sample
